# %% [markdown]
# # EDA

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from dataset.connection import connect_to_spotify_dataset
from dataset.connection import select

# %%
connection = connect_to_spotify_dataset()
if not connection:
    print("Connection Error")
tds = select(connection, "SELECT * FROM track_data")
# Out:
# Connection successful
# Connection closed.

# %%
columns = [
    "id", "name", "popularity", "duration_ms", "explicit", "artists", "id_artists", "release_date",
    "danceability", "energy", "key", "loudness", "mode", "speechiness", "acousticness", 
    "instrumentalness", "liveness", "valence", "tempo", "time_signature"
]
# Create the DataFrame
df = pd.DataFrame(tds, columns=columns)
print(df.dtypes)
df.head()
# Out:
# id                   object
# name                 object
# popularity            int64
# duration_ms           int64
# explicit               bool
# artists              object
# id_artists           object
# release_date         object
# danceability        float64
# energy              float64
# key                   int64
# loudness            float64
# mode                   bool
# speechiness         float64
# acousticness        float64
# instrumentalness    float64
# liveness            float64
# valence             float64
# tempo               float64
# time_signature        int64
# dtype: object
#                        id                                               name  \
# 0  0EhFgTYbaL10BcdwwZAjxK  Chapter 71.2 & Chapter 72.1 - Sprawy Sherlocka...
# 1  0Em99lLhnTCTgG34WwunM6  Chapter 40.2 & Chapter 41.1 - Sprawy Sherlocka...
# 2  0FG1HU2XwTC6jPk2akxjb3                                Train Whistle Blues
# 3  0FnAWRtsJpD1H20X7hHM57    Todo Por Un Amor - Instrumental (Remasterizado)
# 4  0HDjsTcDds6LliCZccZHuH  Chapter 63.2 & Chapter 64.1 - Sprawy Sherlocka...
#
#    popularity  duration_ms  explicit               artists  \
# 0           0       157462     False  [Arthur Conan Doyle]
# 1           0       125144     False  [Arthur Conan Doyle]
# 2           0       177627     False      [Jimmie Rodgers]
# 3           0       173413     False    [Francisco Canaro]
# 4           0       137436     False  [Arthur Conan Doyle]
#
#                  id_artists release_date  danceability  energy  key  loudness  \
# 0  [2AcBhTO6Q3zzUrfPKmskp3]   1927-07-29         0.617   0.213    1   -19.630
# 1  [2AcBhTO6Q3zzUrfPKmskp3]   1927-07-29         0.629   0.280    1   -19.169
# 2  [0Y0ZlznP6vzTS1qAm5dvTN]         1927         0.664   0.543    1    -4.933
# 3  aQMqxNnlRrBrS1oAsrX9]   1927-09-04         0.469   0.285    7   -11.355
# 4  [2AcBhTO6Q3zzUrfPKmskp3]   1927-07-29         0.718   0.288    1   -18.747
#
#     mode  speechiness  acousticness  instrumentalness  liveness  valence  \
# 0   True       0.9570         0.852          0.000000     0.221    0.683
# 1   True       0.9580         0.740          0.000002     0.176    0.759
# 2  False       0.0374         0.972          0.000000     0.320    0.473
# 3  False       0.1940         0.991          0.000265     0.136    0.840
# 4   True       0.9430         0.869          0.000000     0.161    0.791
#
#      tempo  time_signature
# 0  177.175               4
# 1  166.992               5
# 2  110.225               4
# 3  177.733               3
# 4  127.332               4

# %%
df
# Out:
#                             id  \
# 0       0EhFgTYbaL10BcdwwZAjxK
# 1       0Em99lLhnTCTgG34WwunM6
# 2       0FG1HU2XwTC6jPk2akxjb3
# 3       0FnAWRtsJpD1H20X7hHM57
# 4       0HDjsTcDds6LliCZccZHuH
# ...                        ...
# 586667  0BGbtGJh1E9Jbe96CHkcIU
# 586668  0BvDrwk5cPgEZm6tFucL5g
# 586669  0C3yRrF5hrzGLgkzuuEapb
# 586670  0DAyqkfLj6WA0gQhE5cQri
# 586671  0EC4KZNGG67vatZNGxS8kg
#
#                                                      name  popularity  \
# 0       Chapter 71.2 & Chapter 72.1 - Sprawy Sherlocka...           0
# 1       Chapter 40.2 & Chapter 41.1 - Sprawy Sherlocka...           0
# 2                                     Train Whistle Blues           0
# 3         Todo Por Un Amor - Instrumental (Remasterizado)           0
# 4       Chapter 63.2 & Chapter 64.1 - Sprawy Sherlocka...           0
# ...                                                   ...         ...
# 586667                       Sueño Gaucho - Remasterizado           0
# 586668  Chapter 60.2 & Chapter 61 & Chapter 62.1 - Spr...           0
# 586669  Chapter 117.2 & Chapter 118.1 - Sprawy Sherloc...           0
# 586670      Como te Quería - Instrumental (Remasterizado)           0
# 586671  Chapter 247.2 & Chapter 248.1 - Sprawy Sherloc...           0
#
#         duration_ms  explicit               artists                id_artists  \
# 0            157462     False  [Arthur Conan Doyle]  [2AcBhTO6Q3zzUrfPKmskp3]
# 1            125144     False  [Arthur Conan Doyle]  [2AcBhTO6Q3zzUrfPKmskp3]
# 2            177627     False      [Jimmie Rodgers]  [0Y0ZlznP6vzTS1qAm5dvTN]
# 3            173413     False    [Francisco Canaro]  aQMqxNnlRrBrS1oAsrX9]
# 4            137436     False  [Arthur Conan Doyle]  [2AcBhTO6Q3zzUrfPKmskp3]
# ...             ...       ...                   ...                       ...
# 586667       165733     False     [Ignacio Corsini]  [5LiOoJbxVSAMkBS2fUm3X2]
# 586668       125791     False  [Arthur Conan Doyle]  [2AcBhTO6Q3zzUrfPKmskp3]
# 586669       145766     False  [Arthur Conan Doyle]  [2AcBhTO6Q3zzUrfPKmskp3]
# 586670       186027     False    [Francisco Canaro]  aQMqxNnlRrBrS1oAsrX9]
# 586671       151815     False  [Arthur Conan Doyle]  [2AcBhTO6Q3zzUrfPKmskp3]
#
#        release_date  danceability  energy  key  loudness   mode  speechiness  \
# 0        1927-07-29         0.617   0.213    1   -19.630   True       0.9570
# 1        1927-07-29         0.629   0.280    1   -19.169   True       0.9580
# 2              1927         0.664   0.543    1    -4.933  False       0.0374
# 3        1927-09-04         0.469   0.285    7   -11.355  False       0.1940
# 4        1927-07-29         0.718   0.288    1   -18.747   True       0.9430
# ...             ...           ...     ...  ...       ...    ...          ...
# 586667   1927-05-14         0.483   0.393    5   -15.239  False       0.1080
# 586668   1927-07-29         0.718   0.234    1   -18.932   True       0.9420
# 586669   1927-07-29         0.713   0.288    1   -17.765   True       0.9590
# 586670   1927-09-17         0.497   0.327    4   -16.775  False       0.0947
# 586671   1927-07-29         0.709   0.291    5   -18.317  False       0.9550
#
#         acousticness  instrumentalness  liveness  valence    tempo  \
# 0              0.852          0.000000     0.221    0.683  177.175
# 1              0.740          0.000002     0.176    0.759  166.992
# 2              0.972          0.000000     0.320    0.473  110.225
# 3              0.991          0.000265     0.136    0.840  177.733
# 4              0.869          0.000000     0.161    0.791  127.332
# ...              ...               ...       ...      ...      ...
# 586667         0.960          0.000015     0.135    0.671   93.552
# 586668         0.814          0.000000     0.328    0.860  121.072
# 586669         0.883          0.000000     0.261    0.693   79.552
# 586670         0.988          0.947000     0.106    0.892   70.529
# 586671         0.848          0.000000     0.347    0.848  130.033
#
#         time_signature
# 0                    4
# 1                    5
# 2                    4
# 3                    3
# 4                    4
# ...                ...
# 586667               4
# 586668               4
# 586669               4
# 586670               3
# 586671               5
#
# [586672 rows x 20 columns]

# %%
df['artists'] = df['artists'].apply(tuple)
df = df.drop_duplicates(subset=['name', 'artists'], keep='first')

# %%
df
# Out:
#                             id  \
# 0       0EhFgTYbaL10BcdwwZAjxK
# 1       0Em99lLhnTCTgG34WwunM6
# 2       0FG1HU2XwTC6jPk2akxjb3
# 3       0FnAWRtsJpD1H20X7hHM57
# 4       0HDjsTcDds6LliCZccZHuH
# ...                        ...
# 586667  0BGbtGJh1E9Jbe96CHkcIU
# 586668  0BvDrwk5cPgEZm6tFucL5g
# 586669  0C3yRrF5hrzGLgkzuuEapb
# 586670  0DAyqkfLj6WA0gQhE5cQri
# 586671  0EC4KZNGG67vatZNGxS8kg
#
#                                                      name  popularity  \
# 0       Chapter 71.2 & Chapter 72.1 - Sprawy Sherlocka...           0
# 1       Chapter 40.2 & Chapter 41.1 - Sprawy Sherlocka...           0
# 2                                     Train Whistle Blues           0
# 3         Todo Por Un Amor - Instrumental (Remasterizado)           0
# 4       Chapter 63.2 & Chapter 64.1 - Sprawy Sherlocka...           0
# ...                                                   ...         ...
# 586667                       Sueño Gaucho - Remasterizado           0
# 586668  Chapter 60.2 & Chapter 61 & Chapter 62.1 - Spr...           0
# 586669  Chapter 117.2 & Chapter 118.1 - Sprawy Sherloc...           0
# 586670      Como te Quería - Instrumental (Remasterizado)           0
# 586671  Chapter 247.2 & Chapter 248.1 - Sprawy Sherloc...           0
#
#         duration_ms  explicit                artists  \
# 0            157462     False  (Arthur Conan Doyle,)
# 1            125144     False  (Arthur Conan Doyle,)
# 2            177627     False      (Jimmie Rodgers,)
# 3            173413     False    (Francisco Canaro,)
# 4            137436     False  (Arthur Conan Doyle,)
# ...             ...       ...                    ...
# 586667       165733     False     (Ignacio Corsini,)
# 586668       125791     False  (Arthur Conan Doyle,)
# 586669       145766     False  (Arthur Conan Doyle,)
# 586670       186027     False    (Francisco Canaro,)
# 586671       151815     False  (Arthur Conan Doyle,)
#
#                       id_artists release_date  danceability  energy  key  \
# 0       [2AcBhTO6Q3zzUrfPKmskp3]   1927-07-29         0.617   0.213    1
# 1       [2AcBhTO6Q3zzUrfPKmskp3]   1927-07-29         0.629   0.280    1
# 2       [0Y0ZlznP6vzTS1qAm5dvTN]         1927         0.664   0.543    1
# 3       aQMqxNnlRrBrS1oAsrX9]   1927-09-04         0.469   0.285    7
# 4       [2AcBhTO6Q3zzUrfPKmskp3]   1927-07-29         0.718   0.288    1
# ...                          ...          ...           ...     ...  ...
# 586667  [5LiOoJbxVSAMkBS2fUm3X2]   1927-05-14         0.483   0.393    5
# 586668  [2AcBhTO6Q3zzUrfPKmskp3]   1927-07-29         0.718   0.234    1
# 586669  [2AcBhTO6Q3zzUrfPKmskp3]   1927-07-29         0.713   0.288    1
# 586670  aQMqxNnlRrBrS1oAsrX9]   1927-09-17         0.497   0.327    4
# 586671  [2AcBhTO6Q3zzUrfPKmskp3]   1927-07-29         0.709   0.291    5
#
#         loudness   mode  speechiness  acousticness  instrumentalness  \
# 0        -19.630   True       0.9570         0.852          0.000000
# 1        -19.169   True       0.9580         0.740          0.000002
# 2         -4.933  False       0.0374         0.972          0.000000
# 3        -11.355  False       0.1940         0.991          0.000265
# 4        -18.747   True       0.9430         0.869          0.000000
# ...          ...    ...          ...           ...               ...
# 586667   -15.239  False       0.1080         0.960          0.000015
# 586668   -18.932   True       0.9420         0.814          0.000000
# 586669   -17.765   True       0.9590         0.883          0.000000
# 586670   -16.775  False       0.0947         0.988          0.947000
# 586671   -18.317  False       0.9550         0.848          0.000000
#
#         liveness  valence    tempo  time_signature
# 0          0.221    0.683  177.175               4
# 1          0.176    0.759  166.992               5
# 2          0.320    0.473  110.225               4
# 3          0.136    0.840  177.733               3
# 4          0.161    0.791  127.332               4
# ...          ...      ...      ...             ...
# 586667     0.135    0.671   93.552               4
# 586668     0.328    0.860  121.072               4
# 586669     0.261    0.693   79.552               4
# 586670     0.106    0.892   70.529               3
# 586671     0.347    0.848  130.033               5
#
# [526393 rows x 20 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 526393 entries, 0 to 586671
# Data columns (total 20 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   id                526393 non-null  object
#  1   name              526393 non-null  object
#  2   popularity        526393 non-null  int64
#  3   duration_ms       526393 non-null  int64
#  4   explicit          526393 non-null  bool
#  5   artists           526393 non-null  object
#  6   id_artists        526393 non-null  object
#  7   release_date      526393 non-null  object
#  8   danceability      526393 non-null  float64
#  9   energy            526393 non-null  float64
#  10  key               526393 non-null  int64
#  11  loudness          526393 non-null  float64
#  12  mode              526393 non-null  bool
#  13  speechiness       526393 non-null  float64
#  14  acousticness      526393 non-null  float64
#  15  instrumentalness  526393 non-null  float64
#  16  liveness          526393 non-null  float64
#  17  valence           526393 non-null  float64
#  18  tempo             526393 non-null  float64
#  19  time_signature    526393 non-null  int64
# dtypes: bool(2), float64(9), int64(4), object(5)
# memory usage: 77.3+ MB

# %%
df['duration_s'] = df['duration_ms'] / 1000
df.describe()
# Out:
# /var/folders/qc/c98b3cz16bdfd88s6hww6clm0000gn/T/ipykernel_27005/2741194978.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['duration_s'] = df['duration_ms'] / 1000
#           popularity   duration_ms                   release_date  \
# count  526393.000000  5.263930e+05                         526393
# mean       27.487619  2.295037e+05  1988-09-22 19:51:54.513300864
# min         0.000000  4.000000e+03            1900-01-01 00:00:00
# 25%        13.000000  1.737140e+05            1974-01-01 00:00:00
# 50%        27.000000  2.141330e+05            1992-01-01 00:00:00
# 75%        40.000000  2.635770e+05            2007-06-04 00:00:00
# max       100.000000  5.621218e+06            2021-04-16 00:00:00
# std        18.311365  1.288367e+05                            NaN
#
#         danceability         energy            key       loudness  \
# count  526393.000000  526393.000000  526393.000000  526393.000000
# mean        0.564116       0.540107       5.219570     -10.269998
# min         0.000000       0.000000       0.000000     -60.000000
# 25%         0.454000       0.341000       2.000000     -12.968000
# 50%         0.578000       0.546000       5.000000      -9.303000
# 75%         0.687000       0.746000       8.000000      -6.531000
# max         0.991000       1.000000      11.000000       5.376000
# std         0.166471       0.251818       3.518661       5.104555
#
#          speechiness   acousticness  instrumentalness       liveness  \
# count  526393.000000  526393.000000     526393.000000  526393.000000
# mean        0.109146       0.452872          0.112973       0.214787
# min         0.000000       0.000000          0.000000       0.000000
# 25%         0.034100       0.101000          0.000000       0.098500
# 50%         0.044600       0.430000          0.000023       0.139000
# 75%         0.078200       0.786000          0.009240       0.279000
# max         0.971000       0.996000          1.000000       1.000000
# std         0.187556       0.347814          0.266390       0.185036
#
#              valence          tempo  time_signature           year  \
# count  526393.000000  526393.000000   526393.000000  526393.000000
# mean        0.552385     118.410019        3.870257    1988.420159
# min         0.000000       0.000000        0.000000    1900.000000
# 25%         0.346000      95.477000        4.000000    1974.000000
# 50%         0.564000     117.234000        4.000000    1992.000000
# 75%         0.769000     136.390000        4.000000    2007.000000
# max         1.000000     246.381000        5.000000    2021.000000
# std         0.257925      29.822083        0.480709      22.781261
#
#           duration_s
# count  526393.000000
# mean      229.503745
# min         4.000000
# 25%       173.714000
# 50%       214.133000
# 75%       263.577000
# max      5621.218000
# std       128.836738

# %%
df.isna().sum()
# Out:
# id                  0
# name                0
# popularity          0
# duration_ms         0
# explicit            0
# artists             0
# id_artists          0
# release_date        0
# danceability        0
# energy              0
# key                 0
# loudness            0
# mode                0
# speechiness         0
# acousticness        0
# instrumentalness    0
# liveness            0
# valence             0
# tempo               0
# time_signature      0
# dtype: int64

# %%
numeric_columns = ['popularity', 'danceability', 'energy', 'tempo', 'valence']
for col in numeric_columns:
    sns.histplot(df[col], kde=True)
    plt.title(f'Distribution of {col}')
    plt.show()

# %%
print(df['artists'].value_counts().head(10))
# Out:
# artists
# (Die drei ???,)                         3856
# (TKKG Retro-Archiv,)                    2006
# (Benjamin Blümchen,)                    1485
# (Bibi Blocksberg,)                      1440
# (Lata Mangeshkar,)                      1086
# (Tomas Bolme, Tintin, Bert-Åke Varg)     905
# (Bibi und Tina,)                         900
# (Francisco Canaro,)                      866
# (Tadeusz Dolega Mostowicz,)              838
# (Fünf Freunde,)                          812
# Name: count, dtype: int64

# %%
#temporal analysis using release date
df['release_date'] = pd.to_datetime(df['release_date'],format='mixed')
df['year'] = df['release_date'].dt.year
releases_by_year = df['year'].value_counts().sort_index()

plt.figure(figsize=(10, 5))
sns.lineplot(x=releases_by_year.index, y=releases_by_year.values)
plt.title('Number of Songs Released Over Time')
plt.xlabel('Year')
plt.ylabel('Number of Songs')
plt.show()
# Out:
# /var/folders/qc/c98b3cz16bdfd88s6hww6clm0000gn/T/ipykernel_27005/862359106.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['release_date'] = pd.to_datetime(df['release_date'],format='mixed')
# /var/folders/qc/c98b3cz16bdfd88s6hww6clm0000gn/T/ipykernel_27005/862359106.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['year'] = df['release_date'].dt.year

# %%
corr_matrix = df.corr()
fig, ax = plt.subplots(figsize=(10, 8)) 
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()

# %%
#no correlation with danceability and popularity
sns.scatterplot(x='danceability', y='popularity', data=df)
plt.title('Danceability vs Popularity')
plt.show()

# %%
#no correlation with tempo and popularity
sns.scatterplot(x='tempo', y='popularity', data=df)
plt.title('Tempo vs Popularity')
plt.show()

# %%
sns.countplot(x='key', data=df)
plt.title('Distribution of Musical Keys')
plt.show()

# %%
sns.countplot(x='mode', data=df)
plt.title('Distribution of Musical Modes')
plt.show()

# %%
#outliers
for col in numeric_columns:
    sns.boxplot(x=df[col])
    plt.title(f'Boxplot of {col}')
    plt.show()

# %%
selected_features = ['danceability', 'energy', 'popularity', 'tempo', 'valence']
sns.pairplot(df[selected_features])
plt.show()

# %%
# Define bin edges (5-year intervals from min year to 2020.)
min_year = df["year"].min()
bins = np.arange(min_year, 2030, 5)  # 2025 ensures it includes 2020

print('Earliest release date in database: ' + str(df["release_date"].min()) + ' Latest release date in database: ' + str(df["release_date"].max()))

# Create the histogram
plt.figure(figsize=(12, 6))
plt.hist(df["year"], bins=bins, edgecolor="black", alpha=0.7)

# Formatting
plt.xlabel("Release Year")
plt.ylabel("Number of Songs")
plt.title("Distribution of Songs by Release Year (5-Year Bins)")
plt.xticks(bins, rotation=45)  # Rotate for better readability
plt.grid(axis="y", linestyle="--", alpha=0.7)

# Show the plot
plt.show()
# Out:
# Earliest release date in database: 1900-01-01 00:00:00 Latest release date in database: 2021-04-16 00:00:00

# %%
plt.figure(figsize=(8, 4))
sns.boxplot(x=df['duration_s'])

# Show the plot
plt.title("Boxplot of Song/Podcast Durations")
plt.xlabel("Duration (seconds)")
plt.show()

# %%
Q1 = df['duration_s'].quantile(0.25)
Q3 = df['duration_s'].quantile(0.75)
IQR = Q3 - Q1

# Outlier threshold: 1.5 * IQR rule
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Find potential podcast durations (outliers)
potential_outliers = df[df['duration_s'] > upper_bound]
potential_outliers
# Out:
#                             id  \
# 67      0kv2jK5ZMTLiPPKxm6aO06
# 339     2ttGBcNwOJ4HUtllNpdgqu
# 342     2v6NmFhSTX8UtkQXBAUmfx
# 387     3AqImaEBOs4rJO0AdYbGcg
# 602     4mL3oaTRpG3wusDu4oiYd4
# ...                        ...
# 586245  3sojgqU46tV9hbfeqWmzBt
# 586423  5Nj3ZyQB8UFgLPCbH0he0r
# 586455  5huNRasbP9KCRtUSnsumWr
# 586476  5sa5rbjzqPwBQ8KRXffORV
# 586482  5w7Nn9t69OzoISTU0337Wc
#
#                                                      name  popularity  \
# 67      Music To Goethe's Tragedy "Egmont", Op. 84: Ov...           0
# 339     Die Rose vom Liebesgarten - Zwischenspiele: Fu...           0
# 342        Das Christelflein, Op. 20: Overture - Excerpts           0
# 387          Carmen : Acte I - Parle moi de ma mère (Duo)           0
# 602                  Parsifal, WWV 111: Good Friday Music           2
# ...                                                   ...         ...
# 586245                                             Onzory           0
# 586423                          Al Eh Helef Maykalemneesh           1
# 586455                      The Flying Dutchman: Overture           2
# 586476                              Wallahy Mahadesh Gana           0
# 586482                               Khayef Yekoon Hobbak           0
#
#         duration_ms  explicit  \
# 67           524062     False
# 339          434031     False
# 342          431103     False
# 387          541267     False
# 602          557746     False
# ...             ...       ...
# 586245       510773     False
# 586423       418987     False
# 586455       579507     False
# 586476       418520     False
# 586482       411880     False
#
#                                                   artists  \
# 67      (Staatskapelle Berlin, Otto Klemperer, Ludwig ...
# 339                 (Staatskapelle Berlin, Hans Pfitzner)
# 342     (Hans Pfitzner, Mitglieder der Kapelle der Sta...
# 387     (Yvonne Brothier, José De Trévi, Piero Coppola...
# 602     (Richard Wagner, Staatskapelle Berlin, Max von...
# ...                                                   ...
# 586245                                     (Umm Kulthum,)
# 586423                                     (Umm Kulthum,)
# 586455  (Richard Wagner, Staatskapelle Berlin, Max von...
# 586476                                     (Umm Kulthum,)
# 586482                                     (Umm Kulthum,)
#
#                                                id_artists release_date  \
# 67      [2wOqMjp9TyABvtHdOSOTUS, 7vEPPI71V8dEHtEhPMAxW...   1927-01-01
# 339      [5fKj8IWs9IV1F2xerI6SGD, 7vEPPI71V8dEHtEhPMAxWT]   1927-01-01
# 342      [5fKj8IWs9IV1F2xerI6SGD, 5LKRtAMVYCIdYNKMmnV6uo]   1927-01-01
# 387     [37dgRh2i6zUNeHjMLCQSw9, 5vLIUoiN4ndwOMB6suHSN...   1927-01-01
# 602     [1C1x4MVkql8AiABuTw6DgE, 7vEPPI71V8dEHtEhPMAxW...   1927-01-01
# ...                                                   ...          ...
# 586245                           [52lsD82iOqGtyfEMqWgk4f]   1926-01-01
# 586423                           [52lsD82iOqGtyfEMqWgk4f]   1926-01-01
# 586455  [1C1x4MVkql8AiABuTw6DgE, 7vEPPI71V8dEHtEhPMAxW...   1926-01-01
# 586476                           [52lsD82iOqGtyfEMqWgk4f]   1926-01-01
# 586482                           [52lsD82iOqGtyfEMqWgk4f]   1926-01-01
#
#         danceability  energy  ...   mode  speechiness  acousticness  \
# 67             0.289  0.1030  ...  False       0.0545         0.985
# 339            0.163  0.1930  ...   True       0.0537         0.992
# 342            0.272  0.1720  ...   True       0.0455         0.989
# 387            0.323  0.1250  ...   True       0.0554         0.990
# 602            0.136  0.1450  ...  False       0.0423         0.976
# ...              ...     ...  ...    ...          ...           ...
# 586245         0.398  0.0647  ...   True       0.0419         0.985
# 586423         0.427  0.0582  ...   True       0.0988         0.996
# 586455         0.250  0.2740  ...   True       0.0426         0.995
# 586476         0.352  0.1930  ...  False       0.0642         0.927
# 586482         0.313  0.2810  ...  False       0.0753         0.887
#
#         instrumentalness  liveness  valence    tempo  time_signature  year  \
# 67              0.203000     0.143   0.1440   78.416               3  1927
# 339             0.840000     0.143   0.0367   82.422               4  1927
# 342             0.911000     0.112   0.0912   97.265               4  1927
# 387             0.000405     0.646   0.1710   86.244               3  1927
# 602             0.872000     0.403   0.0386   72.145               3  1927
# ...                  ...       ...      ...      ...             ...   ...
# 586245          0.010900     0.130   0.2640   99.376               4  1926
# 586423          0.641000     0.275   0.4320   66.057               4  1926
# 586455          0.850000     0.231   0.0392  126.489               3  1926
# 586476          0.040900     0.402   0.2380  140.356               4  1926
# 586482          0.302000     0.138   0.2080  129.612               3  1926
#
#         duration_s
# 67         524.062
# 339        434.031
# 342        431.103
# 387        541.267
# 602        557.746
# ...            ...
# 586245     510.773
# 586423     418.987
# 586455     579.507
# 586476     418.520
# 586482     411.880
#
# [22706 rows x 22 columns]
