# %% [markdown]
# # K-Means

# %%
import sys
from pathlib import Path
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import psycopg2.extras

root_path = Path().resolve().parent.parent
sys.path.append(str(root_path))

from src.dataset.connection import connect_to_spotify_dataset
from src.dataset.connection import select

from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler

import torch
import torch.nn.functional as F

# %%
connection = connect_to_spotify_dataset() # Add db Password
if not connection:
    print("Connection Error")
tds = select(connection, "SELECT * FROM track_data")
# Out:
# Connection successful
# Connection closed.

# %%
columns = [
    "id", "name", "popularity", "duration_ms", "explicit", "artists", "id_artists", "release_date",
    "danceability", "energy", "key", "loudness", "mode", "speechiness", "acousticness", 
    "instrumentalness", "liveness", "valence", "tempo", "time_signature","decade", "mood_index", "emotion_index", "party_index", "chill_index"
]
# Create the DataFrame
df = pd.DataFrame(tds, columns=columns)
print(df.dtypes)
df.head()
# Out:
# id                   object
# name                 object
# popularity            int64
# duration_ms           int64
# explicit               bool
# artists              object
# id_artists           object
# release_date         object
# danceability        float64
# energy              float64
# key                   int64
# loudness            float64
# mode                   bool
# speechiness         float64
# acousticness        float64
# instrumentalness    float64
# liveness            float64
# valence             float64
# tempo               float64
# time_signature        int64
# decade                int64
# mood_index          float64
# emotion_index       float64
# party_index         float64
# chill_index         float64
# dtype: object
#                        id                                               name  \
# 0  1mC0LEmjbCXjs8jjnYIjHw  Yo También Era Dichoso - Instrumental (Remaste...
# 1  21010f0ucoaLEEn4khQKZb                                        T for Texas
# 2  2fPzoKtGjXFDgzIOSAfrEq  Chapter 1 & Chapter 2.1 - Sprawy Sherlocka Hol...
# 3  3B6gBlf64fMQY3sbkyFENu                                        Purple Daze
# 4  3KD6IGlsy0OmvQ5EZVSGwf                                 Iris: Inno al sole
#
#    popularity  duration_ms  explicit                                  artists  \
# 0           0       170933     False                       [Francisco Canaro]
# 1           1       208000     False                         [Jimmie Rodgers]
# 2           0       128038     False                     [Arthur Conan Doyle]
# 3           0       192332     False                       [Cellular Project]
# 4           0       231987     False  [Pietro Mascagni, Staatskapelle Berlin]
#
#                                          id_artists release_date  \
# 0                          aQMqxNnlRrBrS1oAsrX9]   1927-09-11
# 1                          [0Y0ZlznP6vzTS1qAm5dvTN]         1927
# 2                          [2AcBhTO6Q3zzUrfPKmskp3]   1927-07-29
# 3                          [6OOyYaxY66YrMwusS1PIr6]         1927
# 4  [3Z5fRknMBBNfCw6pkgR9S8, 7vEPPI71V8dEHtEhPMAxWT]   1927-04-01
#
#    danceability  energy  ...  instrumentalness  liveness  valence    tempo  \
# 0         0.808   0.398  ...             0.328     0.173   0.6680  114.891
# 1         0.571   0.718  ...             0.000     0.309   0.5650   78.849
# 2         0.703   0.321  ...             0.000     0.310   0.8030   87.746
# 3         0.344   0.857  ...             0.874     0.125   0.1580  140.669
# 4         0.188   0.139  ...             0.902     0.817   0.0387   74.178
#
#    time_signature  decade  mood_index  emotion_index  party_index  chill_index
# 0               4    1920     0.65600        4.37150       0.6030       0.8024
# 1               4    1920     0.59740        1.61200       0.6445       0.6774
# 2               3    1920     0.67660        5.69210       0.5120       0.7738
# 3               4    1920     0.35360        1.95260       0.6005       0.2312
# 4               3    1920     0.10355        5.63778       0.1635       0.9312
#
# [5 rows x 25 columns]

# %% [markdown]
# # PCA

# %%
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

selected_columns = ['popularity', 'duration_ms', 'explicit', 'danceability', 'energy', 'key',
                    'loudness', 'mode', 'speechiness', 'acousticness', 'instrumentalness',
                    'liveness', 'valence', 'tempo', 'decade',"mood_index","emotion_index","party_index","chill_index"]

X = df[selected_columns]

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

pca = PCA()
X_pca = pca.fit_transform(X_scaled)

# %%
plt.figure(figsize=(10, 5))
plt.plot(range(1, len(selected_columns) + 1), np.cumsum(pca.explained_variance_ratio_), marker='o', linestyle='--')
plt.xlabel('Number of Principal Components')
plt.ylabel('Cumulative Explained Variance')
plt.title('Explained Variance by PCA Components')
plt.grid()
plt.show()

# %%
explained_variance = np.cumsum(pca.explained_variance_ratio_)
n_components = np.argmax(explained_variance >= 0.95) + 1  # Get number of components for 95% variance

print(f"Number of components needed to explain 95% variance: {n_components}")

pca_final = PCA(n_components=n_components)
X_pca_final = pca_final.fit_transform(X_scaled)

df_pca = pd.DataFrame(X_pca_final, columns=[f'PC{i+1}' for i in range(n_components)])
# Out:
# Number of components needed to explain 95% variance: 13

# %%
df_pca
# Out:
#              PC1       PC2       PC3       PC4       PC5       PC6       PC7  \
# 0       1.823652 -2.941102 -0.968966 -0.584327  0.986108 -0.179790  0.398474
# 1       0.367736 -1.409699 -1.670282  1.295385 -0.885038 -1.348382  2.141578
# 2       2.554092 -4.657463  1.888453  1.599435  1.795461  0.033669  0.203990
# 3       0.615676  1.263781 -2.939935  1.337242  0.324782  1.066355 -0.353780
# 4       6.623513  0.935577 -0.835520  3.111189  0.664170  1.409538  1.173034
# ...          ...       ...       ...       ...       ...       ...       ...
# 525582  3.521582 -3.093360  2.906361  2.025112  1.224332  0.747963  0.777937
# 525583  3.872591 -3.247692  2.605968  1.451096  1.233073  0.571663  0.066358
# 525584  2.359059 -2.241527 -2.090643 -0.408973  0.741425  0.306163  0.248950
# 525585  3.949948 -2.786295  2.877097  1.620917  2.328034  0.529651 -0.056581
# 525586  1.571259 -3.037898 -2.073398 -0.406582  0.207623  0.533037  0.486139
#
#              PC8       PC9      PC10      PC11      PC12      PC13
# 0      -1.628679 -0.567399  0.221997 -0.208314 -0.329435  0.368153
# 1      -1.573808  0.875939  0.575058 -0.614133 -0.320171 -0.320742
# 2      -0.254068 -0.914265  0.180363 -1.912765 -0.920434 -1.214302
# 3      -2.166430  1.655458 -1.146505 -1.455600 -1.356830 -0.539754
# 4      -1.349267  1.284934 -0.233185  1.414903  0.364529 -0.095561
# ...          ...       ...       ...       ...       ...       ...
# 525582  1.315022  1.042243 -0.708736 -3.113539 -0.595150 -0.184440
# 525583  1.492890  0.958335 -0.422988 -3.172839 -0.751336 -0.442836
# 525584 -3.003056 -0.280930 -0.264948  0.794708 -1.126944 -0.347654
# 525585  0.516022 -0.629066 -0.690489 -3.067532 -0.343536 -0.404658
# 525586 -1.583932  1.635360 -0.017314  1.220275 -1.393998 -0.260855
#
# [525587 rows x 13 columns]

# %%
# Compute variance of each feature
feature_variance = df[selected_columns].var()

# Sort features by variance (descending order)
feature_variance_sorted = feature_variance.sort_values(ascending=False)

print(feature_variance_sorted)
# Out:
# duration_ms         9.248533e+09
# tempo               8.892337e+02
# decade              5.233641e+02
# popularity          3.352937e+02
# loudness            2.599736e+01
# key                 1.238093e+01
# emotion_index       2.096494e+00
# mode                2.252908e-01
# acousticness        1.209080e-01
# chill_index         8.355716e-02
# instrumentalness    7.084767e-02
# valence             6.646686e-02
# energy              6.337540e-02
# explicit            4.300033e-02
# speechiness         3.490188e-02
# mood_index          3.447737e-02
# liveness            3.409099e-02
# party_index         2.776405e-02
# danceability        2.767026e-02
# dtype: float64

# %% [markdown]
# # K-Means - SKLearn

# %%
df.head()
# Out:
#                        id                                               name  \
# 0  1mC0LEmjbCXjs8jjnYIjHw  Yo También Era Dichoso - Instrumental (Remaste...
# 1  21010f0ucoaLEEn4khQKZb                                        T for Texas
# 2  2fPzoKtGjXFDgzIOSAfrEq  Chapter 1 & Chapter 2.1 - Sprawy Sherlocka Hol...
# 3  3B6gBlf64fMQY3sbkyFENu                                        Purple Daze
# 4  3KD6IGlsy0OmvQ5EZVSGwf                                 Iris: Inno al sole
#
#    popularity  duration_ms  explicit                                  artists  \
# 0           0       170933     False                       [Francisco Canaro]
# 1           1       208000     False                         [Jimmie Rodgers]
# 2           0       128038     False                     [Arthur Conan Doyle]
# 3           0       192332     False                       [Cellular Project]
# 4           0       231987     False  [Pietro Mascagni, Staatskapelle Berlin]
#
#                                          id_artists release_date  \
# 0                          aQMqxNnlRrBrS1oAsrX9]   1927-09-11
# 1                          [0Y0ZlznP6vzTS1qAm5dvTN]         1927
# 2                          [2AcBhTO6Q3zzUrfPKmskp3]   1927-07-29
# 3                          [6OOyYaxY66YrMwusS1PIr6]         1927
# 4  [3Z5fRknMBBNfCw6pkgR9S8, 7vEPPI71V8dEHtEhPMAxWT]   1927-04-01
#
#    danceability  energy  ...  instrumentalness  liveness  valence    tempo  \
# 0         0.808   0.398  ...             0.328     0.173   0.6680  114.891
# 1         0.571   0.718  ...             0.000     0.309   0.5650   78.849
# 2         0.703   0.321  ...             0.000     0.310   0.8030   87.746
# 3         0.344   0.857  ...             0.874     0.125   0.1580  140.669
# 4         0.188   0.139  ...             0.902     0.817   0.0387   74.178
#
#    time_signature  decade  mood_index  emotion_index  party_index  chill_index
# 0               4    1920     0.65600        4.37150       0.6030       0.8024
# 1               4    1920     0.59740        1.61200       0.6445       0.6774
# 2               3    1920     0.67660        5.69210       0.5120       0.7738
# 3               4    1920     0.35360        1.95260       0.6005       0.2312
# 4               3    1920     0.10355        5.63778       0.1635       0.9312
#
# [5 rows x 25 columns]

# %%
#duration, tempo, decade, popularity, key, emotion index, mode, chill index
df_kmeans = df[['duration_ms', 'tempo', 'decade', 'popularity', 'key', 'emotion_index', 'mode', 'chill_index']]
df_kmeans.head()
# Out:
#    duration_ms    tempo  decade  popularity  key  emotion_index   mode  \
# 0       170933  114.891    1920           0    4        4.37150  False
# 1       208000   78.849    1920           1    3        1.61200   True
# 2       128038   87.746    1920           0    6        5.69210  False
# 3       192332  140.669    1920           0    3        1.95260   True
# 4       231987   74.178    1920           0    2        5.63778   True
#
#    chill_index
# 0       0.8024
# 1       0.6774
# 2       0.7738
# 3       0.2312
# 4       0.9312

# %%
#pre-proc
scaler = StandardScaler()
df_scaled = scaler.fit_transform(df_kmeans)

# %%
inertia = []
k_range = range(1, 11)

for k in k_range:
    kmeans = KMeans(n_clusters=k, random_state=42, n_init=10)
    kmeans.fit(df_scaled)
    inertia.append(kmeans.inertia_)  #sum of squared distances to cluster center

# %%
plt.figure(figsize=(8,5))
plt.plot(k_range, inertia, marker='o', linestyle='--')
plt.xlabel('Number of Clusters (K)')
plt.ylabel('Inertia')
plt.title('Optimal K')
plt.show()

# %%
optimal_k = 3 
kmeans = KMeans(n_clusters=optimal_k, random_state=42, n_init=10)
df['Cluster'] = kmeans.fit_predict(df_scaled)

# %%
df.head()
# Out:
#                        id                                               name  \
# 0  1mC0LEmjbCXjs8jjnYIjHw  Yo También Era Dichoso - Instrumental (Remaste...
# 1  21010f0ucoaLEEn4khQKZb                                        T for Texas
# 2  2fPzoKtGjXFDgzIOSAfrEq  Chapter 1 & Chapter 2.1 - Sprawy Sherlocka Hol...
# 3  3B6gBlf64fMQY3sbkyFENu                                        Purple Daze
# 4  3KD6IGlsy0OmvQ5EZVSGwf                                 Iris: Inno al sole
#
#    popularity  duration_ms  explicit                                  artists  \
# 0           0       170933     False                       [Francisco Canaro]
# 1           1       208000     False                         [Jimmie Rodgers]
# 2           0       128038     False                     [Arthur Conan Doyle]
# 3           0       192332     False                       [Cellular Project]
# 4           0       231987     False  [Pietro Mascagni, Staatskapelle Berlin]
#
#                                          id_artists release_date  \
# 0                          aQMqxNnlRrBrS1oAsrX9]   1927-09-11
# 1                          [0Y0ZlznP6vzTS1qAm5dvTN]         1927
# 2                          [2AcBhTO6Q3zzUrfPKmskp3]   1927-07-29
# 3                          [6OOyYaxY66YrMwusS1PIr6]         1927
# 4  [3Z5fRknMBBNfCw6pkgR9S8, 7vEPPI71V8dEHtEhPMAxWT]   1927-04-01
#
#    danceability  energy  ...  liveness  valence    tempo  time_signature  \
# 0         0.808   0.398  ...     0.173   0.6680  114.891               4
# 1         0.571   0.718  ...     0.309   0.5650   78.849               4
# 2         0.703   0.321  ...     0.310   0.8030   87.746               3
# 3         0.344   0.857  ...     0.125   0.1580  140.669               4
# 4         0.188   0.139  ...     0.817   0.0387   74.178               3
#
#    decade  mood_index  emotion_index  party_index  chill_index  Cluster
# 0    1920     0.65600        4.37150       0.6030       0.8024        2
# 1    1920     0.59740        1.61200       0.6445       0.6774        2
# 2    1920     0.67660        5.69210       0.5120       0.7738        2
# 3    1920     0.35360        1.95260       0.6005       0.2312        2
# 4    1920     0.10355        5.63778       0.1635       0.9312        2
#
# [5 rows x 26 columns]

# %% [markdown]
# # K-Means - PyTorch

# %%
#pre-proc
data = torch.tensor(df_scaled, dtype=torch.float32)  #convert to PyTorch tensor
